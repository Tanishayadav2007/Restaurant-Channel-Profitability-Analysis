# %% [markdown]
# # Restaurant Channel Profitability Analysis
#
# ## SkyCity Auckland Restaurants & Bars
#
# ### Objective
#
# Analyze the profitability of multiple restaurant sales channels (In-Store, Uber Eats, DoorDash, and Self-Delivery) by comparing revenue, costs, margins, commissions, and delivery expenses to identify the most profitable and sustainable business strategy.

# %% [markdown]
# ## Import Libraries

# %%
conda install -c plotly plotly
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'D:\New' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings("ignore")
